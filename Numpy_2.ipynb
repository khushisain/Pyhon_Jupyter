# %%
import numpy as np
from numpy import random
arr = np.array([1,2,3,4,5])
random.shuffle(arr)
arr
# Out:
# array([4, 5, 1, 3, 2])

# %%
import numpy as np
from numpy import random
arr = np.array([1,2,3,4,5])
print(random.shuffle(arr))
# Out:
# None

# %%
arr1 = np.array([1,2,3,4,5])
print(random.permutation(arr1))
# Out:
# [3 2 4 1 5]

# %%
arr1 = np.array([1,2,3,4,5])
random.permutation(arr1)
print(arr1)
# Out:
# [1 2 3 4 5]

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot([0,1,2,3,4,5])
plt.show()
# Out:
# C:\Users\khush\AppData\Local\Temp\ipykernel_23440\2208582645.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5])

# %%
sns.distplot([0,1,2,3,4,5,6],hist = False)
plt.show()
# Out:
# C:\Users\khush\AppData\Local\Temp\ipykernel_23440\4050837838.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5,6],hist = False)

# %%
x = random.normal(size=(2,3))
print(x)
# Out:
# [[-0.09797856  0.54053208  1.18666735]
#  [ 1.15975784  0.05913575 -0.76471597]]

# %%
x1 = random.normal(loc = 1,scale = 2, size=(2,3))
print(x1)
# Out:
# [[ 0.22904241 -0.49165672  1.95567579]
#  [ 1.14680108  1.56989657  1.06175584]]

# %%
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(random.normal(size=1000))
plt.show()
# Out:
# C:\Users\khush\AppData\Local\Temp\ipykernel_23440\1879358668.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000))

# %%
sns.distplot(random.normal(size = 1000),hist = False)
plt.show()
# Out:
# C:\Users\khush\AppData\Local\Temp\ipykernel_23440\2176722057.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size = 1000),hist = False)

# %%
from numpy import random
x2 = random.binomial(n=10,p=0.5,size=10)
print(x2)
# Out:
# [7 7 2 2 5 6 4 6 5 5]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.binomial(n=10,p=0.5,size=1000),hist=True,kde=False)
plt.show()
# Out:
# C:\Users\khush\AppData\Local\Temp\ipykernel_23440\4208575294.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10,p=0.5,size=1000),hist=True,kde=False)

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.binomial(n=10,p=0.5,size=1000),hist=True,kde=True)
plt.show()
# Out:
# C:\Users\khush\AppData\Local\Temp\ipykernel_23440\3865720664.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10,p=0.5,size=1000),hist=True,kde=True)

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(random.normal(loc=50, scale=5, size=1000),hist=False,label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000),hist=False, label='binomial')
plt.show()
# Out:
# C:\Users\khush\AppData\Local\Temp\ipykernel_23440\65988912.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=5, size=1000),hist=False,label='normal')
# C:\Users\khush\AppData\Local\Temp\ipykernel_23440\65988912.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
x = [1,2,3,4]
y = [5,6,7,8]
z = []
for i,j in zip(x,y):
    z.append(i+j)
    print(z)
# Out:
# [6]
# [6, 8]
# [6, 8, 10]
# [6, 8, 10, 12]

# %%
x = [1,2,3,4]
y = [5,6,7,8]
z = []
for i,j in zip(x,y):
    z.append(i+j)
print(z)
# Out:
# [6, 8, 10, 12]

# %%
import numpy as np
x = [1,2,3,4]
y = [5,6,7,8]
z = np.add(x,y)
z
# Out:
# array([ 6,  8, 10, 12])

# %%
print(type(np.add))
# Out:
# <class 'numpy.ufunc'>

# %%
print(type(np.concatenate))
# Out:
# <class 'function'>

# %%
x1 = [40,22,43,55,73]
x2 = [3,4,5,7,2]
z = np.add(x1,x2)
z
# Out:
# array([43, 26, 48, 62, 75])

# %%
x1 = [40,22,43,55,73]
x2 = [3,4,5,7,2]
z = np.subtract(x1,x2)
z
# Out:
# array([37, 18, 38, 48, 71])

# %%
x1 = [40,22,43,55,73]
x2 = [3,4,5,7,2]
z = np.multiply(x1,x2)
z
# Out:
# array([120,  88, 215, 385, 146])

# %%
x1 = [40,22,43,55,73]
x2 = [3,4,5,7,2]
z = np.divide(x1,x2)
z
# Out:
# array([13.33333333,  5.5       ,  8.6       ,  7.85714286, 36.5       ])

# %%
x1 = [40,22,43,55,73] #40*40*40  22*22*22*22 and so
x2 = [3,4,5,7,2]
z = np.power(x1,x2)
z
# Out:
# array([     64000,     234256,  147008443, 2016811591,       5329])

# %%
x1 = [40,22,43,55,73] #giving the remindar
x2 = [3,4,5,7,2]
z = np.mod(x1,x2)
z
# Out:
# array([1, 2, 3, 6, 1])

# %%
x1 = [40,22,43,55,73]
x2 = [3,4,5,7,2]
z = np.remainder(x1,x2)
z
# Out:
# array([1, 2, 3, 6, 1])

# %%
x1 = [40,22,43,55,73]
x2 = [3,4,5,7,2]
z = np.divmod(x1,x2)
z
# Out:
# (array([13,  5,  8,  7, 36]), array([1, 2, 3, 6, 1]))

# %%
x1 = [-40,-22,-43,-55,73]
z = np.absolute(x1)
z
# Out:
# array([40, 22, 43, 55, 73])

# %%
y1 = [1,2,3,4]
y2 = [5,6,7,8]
np.add(y1,y2)
# Out:
# array([ 6,  8, 10, 12])

# %%
y1 = [1,2,3,4]
y2 = [5,6,7,8]
z = np.sum([y1,y2])
z
# Out:
# 36

# %%
u1 = [1,2,3,4] #1,1+2,3+3,6+4
np.cumsum(u1)
# Out:
# array([ 1,  3,  6, 10])

# %%
u1 = [1,2,3,4]
np.prod(u1)
# Out:
# 24

# %%
u1 = [1,2,3,4]
u2 = [5,6,7,8]
np.prod([u1,u2])
# Out:
# 40320

# %%
u1 = [1,2,3,4]
u2 = [5,6,7,8]
np.prod([u1,u2],axis=1)
# Out:
# array([  24, 1680])

# %%
u1 = [1,2,3,4]
u2 = [5,6,7,8]
np.cumprod([u1,u2])
# Out:
# array([    1,     2,     6,    24,   120,   720,  5040, 40320])

# %%
d = [5,10,15,20]
np.diff(d)
# Out:
# array([5, 5, 5])

# %%
d = [5,10,15,25,5]
np.diff(d)
# Out:
# array([  5,   5,  10, -20])

# %%
a = 6
b = 9
np.lcm(a,b)
# Out:
# 18

# %%
a = [2,3,4]
np.lcm.reduce(a)
# Out:
# 12

# %%
a = 6
b = 9
np.gcd(a,b)
# Out:
# 3

# %%
a = [6,3,4]
np.gcd.reduce(a)
# Out:
# 1

# %%
arr = np.array([1,2,3])
print(np.cumsum(arr))
# Out:
# [1 3 6]

# %%
arr = np.array([1,2,3])
np.argmax(arr)
# Out:
# 2

# %%
arr = np.array([1,2,3])
np.argmin(arr)
# Out:
# 0

# %%
arr = np.array([1,4,8,2,3])
np.argsort(arr)
# Out:
# array([0, 3, 4, 1, 2], dtype=int64)

# %%
import sys

# %%
ar = [1,2,3,4]
ra = np.array(ar)
sys.getsizeof(1) * len(ar)
# Out:
# 112

# %%
import numpy as np
print(np.__version__)
print(np.__config__)
print(np.show_config())
# Out:
# 1.24.3
# <module 'numpy.__config__' from 'C:\\Users\\khush\\anaconda3\\Lib\\site-packages\\numpy\\__config__.py'>
# blas_armpl_info:
#   NOT AVAILABLE
# blas_mkl_info:
#     libraries = ['mkl_rt']
#     library_dirs = ['C:/Users/khush/anaconda3\\Library\\lib']
#     define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#     include_dirs = ['C:/Users/khush/anaconda3\\Library\\include']
# blas_opt_info:
#     libraries = ['mkl_rt']
#     library_dirs = ['C:/Users/khush/anaconda3\\Library\\lib']
#     define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#     include_dirs = ['C:/Users/khush/anaconda3\\Library\\include']
# lapack_armpl_info:
#   NOT AVAILABLE
# lapack_mkl_info:
#     libraries = ['mkl_rt']
#     library_dirs = ['C:/Users/khush/anaconda3\\Library\\lib']
#     define_macros = [('SCIPY_MKL_H', None), ('HAVE_CBLAS', None)]
#     include_dirs = ['C:/Users/khush/anaconda3\\Library\\include']
# lapack_opt_info:
#     libraries = ['mkl_rt']
# ...
